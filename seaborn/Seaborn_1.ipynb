# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import seaborn as sns
import plotly.express as px

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# scatter plot -> axes level function
sns.scatterplot(data=tips,x="total_bill",y="tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# scatter plot as in replot->figure level->square shape
sns.relplot(data=tips,x="total_bill",y="tip",kind="scatter",hue="sex",style="time",size="size")

# %%
# line plot
gap=px.data.gapminder()
temp_df=gap[gap["country"]=="India"]
temp_df
# Out:
#     country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696   India      Asia  1952   37.373   372000000   546.565749       IND
# 697   India      Asia  1957   40.249   409000000   590.061996       IND
# 698   India      Asia  1962   43.605   454000000   658.347151       IND
# 699   India      Asia  1967   47.193   506000000   700.770611       IND
# 700   India      Asia  1972   50.651   567000000   724.032527       IND
# 701   India      Asia  1977   54.208   634000000   813.337323       IND
# 702   India      Asia  1982   56.596   708000000   855.723538       IND
# 703   India      Asia  1987   58.553   788000000   976.512676       IND
# 704   India      Asia  1992   60.223   872000000  1164.406809       IND
# 705   India      Asia  1997   61.765   959000000  1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547  1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 696      356
# ...

# %%
# axxes level function
sns.lineplot(data=temp_df,x="year",y="lifeExp")
# Out:
# <AxesSubplot:xlabel='year', ylabel='lifeExp'>

# %%
sns.relplot(data=temp_df,x="year",y="lifeExp",kind="line")

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
p=px.data.gapminder()
temp_df2=p[p["country"].isin(["India","China","Pakistan"])]
temp_df2
# Out:
#        country continent  year   lifeExp         pop    gdpPercap iso_alpha  \
# 288      China      Asia  1952  44.00000   556263527   400.448611       CHN
# 289      China      Asia  1957  50.54896   637408000   575.987001       CHN
# 290      China      Asia  1962  44.50136   665770000   487.674018       CHN
# 291      China      Asia  1967  58.38112   754550000   612.705693       CHN
# 292      China      Asia  1972  63.11888   862030000   676.900092       CHN
# 293      China      Asia  1977  63.96736   943455000   741.237470       CHN
# 294      China      Asia  1982  65.52500  1000281000   962.421381       CHN
# 295      China      Asia  1987  67.27400  1084035000  1378.904018       CHN
# 296      China      Asia  1992  68.69000  1164970000  1655.784158       CHN
# 297      China      Asia  1997  70.42600  1230075000  2289.234136       CHN
# 298      China      Asia  2002  72.02800  1280400000  3119.280896       CHN
# ...

# %%
sns.relplot(kind="line",data=temp_df2,x="year",y="lifeExp",hue="country")

# %%
sns.lineplot(data=temp_df2,x="year",y="lifeExp",hue="country")
# Out:
# <AxesSubplot:xlabel='year', ylabel='lifeExp'>

# %%
p=px.data.gapminder()
temp_df3=p[p["country"].isin(["India","Aferica","Germany"])]
temp_df3
# Out:
#      country continent  year  lifeExp         pop     gdpPercap iso_alpha  \
# 564  Germany    Europe  1952   67.500    69145952   7144.114393       DEU
# 565  Germany    Europe  1957   69.100    71019069  10187.826650       DEU
# 566  Germany    Europe  1962   70.300    73739117  12902.462910       DEU
# 567  Germany    Europe  1967   70.800    76368453  14745.625610       DEU
# 568  Germany    Europe  1972   71.000    78717088  18016.180270       DEU
# 569  Germany    Europe  1977   72.500    78160773  20512.921230       DEU
# 570  Germany    Europe  1982   73.800    78335266  22031.532740       DEU
# 571  Germany    Europe  1987   74.847    77718298  24639.185660       DEU
# 572  Germany    Europe  1992   76.070    80597764  26505.303170       DEU
# 573  Germany    Europe  1997   77.340    82011073  27788.884160       DEU
# 574  Germany    Europe  2002   78.670    82350671  30035.801980       DEU
# 575  Germany    Europe  2007   79.406    82400996  32170.374420       DEU
# ...

# %%
sns.relplot(kind="line",data=temp_df3,x="year",y="lifeExp",hue="country",style="continent",size="continent")

# %%
sns.relplot(kind="scatter",data=tips,x="total_bill",y="tip",hue="sex")

# %%
# facet plot->simailar as subplot->and it work only figure level function
# its doesnt work on the scatter means direct cant work
sns.relplot(data=tips,x="total_bill",y="tip",col="sex",row="day",kind="scatter")

# %%
sns.relplot(data=gap,x="lifeExp",y="gdpPercap",kind="scatter",col="year",col_wrap=4)

# %%
# distrubtion plot 
# figure level->displot
# axis level->hist graph

# %%
sns.histplot(data=tips,x="total_bill",bins=2)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.displot(data=tips,x="total_bill",kind="hist")

# %%
tips

sns.displot(data=tips,x="tip",kind="hist",hue="sex",element="step")

# %%
titanic=sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.displot(data=titanic,x="age",kind="hist",hue="sex",element="step")

# %%
# faceting using cl and row ->not work on histplot function
sns.displot(data=titanic,x="age",kind="hist",col="sex",element="step")

# %%
# kdplot->
# its also a axises function graph

tips=sns.load_dataset("tips")
tips
sns.kdeplot(data=tips,x="total_bill")
# density is the probablity
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
# displot ->kdeplot
sns.displot(data=tips,x="total_bill",kind="kde")

# %%
# hue
# sns.displot(data=tips,x="total_bill",kind="kde",col="sex",)
sns.displot(data=tips,x="total_bill",kind="kde",hue="sex")

# %%
# rugplot
# this is not so usefull 
sns.kdeplot(data=tips,x="total_bill")
sns.rugplot(data=tips,x="total_bill")

# rugplot is also part of probablity or density
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
# Bivariate -Histogram
sns.histplot(data=tips,x="total_bill",y="tip")
sns.displot(data=tips,x="total_bill",y="tip",kind="hist",hue="day")

plt.grid()

# %%
# Bivariate Kdeplot
sns.kdeplot(data=tips,x="total_bill",y="tip")
plt.grid()
plt.show()

# %%
# matrix graph
gap=px.data.gapminder()
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
life=gap.pivot(index="country",columns="year",values="lifeExp")

# %%
# axeslevel function
plt.figure(figsize=(15,15))
sns.heatmap(data=life)
plt.show()

# %%
live_3=gap[gap["continent"]=="Europe"].pivot(index="country",columns="year",values="lifeExp")

plt.figure(figsize=(15,15))
sns.heatmap(data=live_3,annot=True,linewidths=0.5,cmap="summer")
plt.show()

# %%
# cluster map
irsi=px.data.iris()
irsi
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
sns.clustermap(irsi.iloc[:,[0,1,2,3]])
